# %% [markdown]
# ## Projeto de digitação dos pedidos direto loja

# %% [markdown]
# ## Instalando a biblioteca do Pyautogui

# %%
#!pip install pyautogui

# %% [markdown]
# ## Importando as bibliotecas necessárias

# %%
#1 Importar todas as bibliotecas necessárias para a aplicação

import pyautogui
import time
import pandas as pd

# %%
#2 Acessar o sistema RMS

def acessar_RMS(): 
        
    # Acessa o atalho do RMS
    pyautogui.click(x=39, y=351, clicks=2)
    time.sleep(2)

    # Loga com a senha do usuário
    
    pyautogui.write('dion')
    pyautogui.press('tab')
    pyautogui.write('002259')
    pyautogui.press("enter", presses=3, interval=0.3)

# %%
# Com a tela Maximilizada!
#3 Acessar o modulo de "Compras Filial"

def acessar_compras():
    
    time.sleep(2)    
    pyautogui.click(x=381, y=113, clicks=2)
    pyautogui.click(x=10, y=194)
    pyautogui.click(x=28, y=268)
    pyautogui.click(x=111, y=282, clicks=2)

# %%
#4 Acessar o modulo de troca de loja
# Função de troca de loja

def alterar_loja():
    
    time.sleep(2)
    pyautogui.click(x=805, y=1030)

# %%
#5 Carregar as funções para utilização interna
# Função de Seleção de cada loja

def lj26():
    pyautogui.press("up", interval=0.1)
    
def lj29():
    pyautogui.press("down", presses=2, interval=0.1)

def lj31():
    pyautogui.press("down", presses=3, interval=0.1)

def lj41():
    pyautogui.press("down", presses=4, interval=0.1)

def lj17():
    pyautogui.press("down", presses=5, interval=0.1)

def lj27():
    pyautogui.press("down", presses=6, interval=0.1)

def lj05():
    pyautogui.press("down", presses=8, interval=0.1)

def lj20():
    pyautogui.press("down", presses=9, interval=0.1)

def lj24():
    pyautogui.press("down", presses=12, interval=0.1)

def lj40():
    pyautogui.press("down", presses=13, interval=0.1)

def lj12():
    pyautogui.press("down", presses=14, interval=0.1)

def lj22():
    pyautogui.press("down", presses=15, interval=0.1)

def lj08():
    pyautogui.press("down", presses=16, interval=0.1)

def lj13():
    pyautogui.press("down", presses=17, interval=0.1)

def lj15():
    pyautogui.press("down", presses=19, interval=0.1)

def lj28():
    pyautogui.press("down", presses=20, interval=0.1)

def lj02():
    pyautogui.press("down", presses=23, interval=0.1)

def lj11():
    pyautogui.press("down", presses=24, interval=0.1)

def lj23():
    pyautogui.press("down", presses=25, interval=0.1)

def lj19():
    pyautogui.press("down", presses=26, interval=0.1)

# %%
#6 Seleciona a loja e carrega aguardando o comprador padrão
# Função de escolha das lojas

def selecionar_loja():
    
    pyautogui.press("tab", interval=0.1)
    pyautogui.press("enter", interval=0.1)
    pyautogui.press("left", interval=0.1)
    pyautogui.press("enter", interval=0.1)

# %%
#7 Carregar as funções para utilização interna  
# Função de Geração do pedido direto loja

def gerar_pedido():
    
    time.sleep(1)
    pyautogui.PAUSE = 0.2
                
    if numfor:
        pyautogui.write('999')
        pyautogui.press("enter")
        pyautogui.press("f6")
        pyautogui.write (str("{}\n".format(numfor)),interval=0.2)
        pyautogui.press("enter")
        time.sleep(5)
        pyautogui.press("enter")
        pyautogui.press("enter", presses=12, interval=0.2)
        pyautogui.write('20\n')
        pyautogui.press("f4")
        time.sleep(25)
        pyautogui.press("f3")
        pyautogui.click(x=1142, y=432)
        pyautogui.press("f9")
        time.sleep(10)
        # Ir para a próxima loja e gerar os demais pedidos...

# %%
#8 Gerar os arquivos com os pedidos
# Função Gerar arquivo de pedido

def gerar_arquivos():
    
    pyautogui.hotkey("shift","f2")
    pyautogui.hotkey("shift","f3")
    pyautogui.press("enter", presses=2, interval=0.1)

# %%
#8 Carregar as funções para utilização interna
# Função de execução de Todas as Lojas

def todas_lojas():
            
    lojas = ['26','29','31','41','17','27','5','20','24','40','12','22','8','13','15','28','21','2','11','23','19']
    i = 0
   
    numloja = lojas[i]
                    
    while i < len(lojas):
                        
        numloja = lojas[i]
        
        if numloja == "26":
            alterar_loja()
            lj26()
            selecionar_loja()
            gerar_pedido()

        elif numloja == "29":
            alterar_loja()
            lj29()
            selecionar_loja()
            gerar_pedido()

        elif numloja == "31":
            alterar_loja()
            lj31()
            selecionar_loja()
            gerar_pedido()

        elif numloja == "41":
            alterar_loja()
            lj41()
            selecionar_loja()
            gerar_pedido()

        elif numloja == "17":
            alterar_loja()
            lj17()
            selecionar_loja()
            gerar_pedido()

        elif numloja == "27":
            alterar_loja()
            lj27()
            selecionar_loja()
            gerar_pedido()

        elif numloja == "5":
            alterar_loja()
            lj05()
            selecionar_loja()
            gerar_pedido()

        elif numloja == "20":
            alterar_loja()
            lj20()
            selecionar_loja()
            gerar_pedido()

        elif numloja == "24":
            alterar_loja()
            lj24()
            selecionar_loja()
            gerar_pedido()

        elif numloja == "40":
            alterar_loja()
            lj40()
            selecionar_loja()
            gerar_pedido()

        elif numloja == "12":
            alterar_loja()
            lj12()
            selecionar_loja()
            gerar_pedido()

        elif numloja == "22":
            alterar_loja()
            lj22()
            selecionar_loja()
            gerar_pedido()

        elif numloja == "8":
            alterar_loja()
            lj08()
            selecionar_loja()
            gerar_pedido()

        elif numloja == "13":
            alterar_loja()
            lj13()
            selecionar_loja()
            gerar_pedido()

        elif numloja == "15":
            alterar_loja()
            lj15()
            selecionar_loja()
            gerar_pedido()

        elif numloja == "28":
            alterar_loja()
            lj28()
            selecionar_loja()
            gerar_pedido()
            
        elif numloja == "2":
            alterar_loja()
            lj02()
            selecionar_loja()
            gerar_pedido()

        elif numloja == "11":
            alterar_loja()
            lj11()
            selecionar_loja()
            gerar_pedido()

        elif numloja == "23":
            alterar_loja()
            lj23()
            selecionar_loja()
            gerar_pedido()

        elif numloja == "19":
            alterar_loja()
            lj19()
            selecionar_loja()
            gerar_pedido()

        else:
            pyautogui.alert("Todos os Pedidos foram Realizados!", title="Conclusão dos Pedidos")
            
        i = i + 1

# %%
#9 Carregar as funções para utilização interna
# Função de acesso loja a loja

def loja_loja():
    
    pyautogui.PAUSE = 0.3
    
    numloja = pyautogui.prompt("Iniciar a partir de qual loja?", title="Informar número da loja")
                                          
    lojas = ["26","29","31","41","17","27","5","20","24","40","12","22","8","13","15","28","2","11","23","19"]
    
    while numloja:
        
        if numloja in lojas:
            
            i = lojas.index(numloja)
            
            if numloja == "26":
                
                alterar_loja()
                lj26()
                selecionar_loja()
                gerar_pedido()
                i = i + 1
                numloja = lojas[i]

            elif numloja == "29":
                alterar_loja()
                lj29()
                selecionar_loja()
                gerar_pedido()
                i = i + 1
                numloja = lojas[i]

            elif numloja == "31":
                alterar_loja()
                lj31()
                selecionar_loja()
                gerar_pedido()
                i = i + 1
                numloja = lojas[i]

            elif numloja == "41":
                alterar_loja()
                lj41()
                selecionar_loja()
                gerar_pedido()
                i = i + 1
                numloja = lojas[i]

            elif numloja == "17":
                alterar_loja()
                lj17()
                selecionar_loja()
                gerar_pedido()
                i = i + 1
                numloja = lojas[i]

            elif numloja == "27":
                alterar_loja()
                lj27()
                selecionar_loja()
                gerar_pedido()
                i = i + 1
                numloja = lojas[i]

            elif numloja == "5":
                alterar_loja()
                lj05()
                selecionar_loja()
                gerar_pedido()
                i = i + 1
                numloja = lojas[i]

            elif numloja == "20":
                alterar_loja()
                lj20()
                selecionar_loja()
                gerar_pedido()
                i = i + 1
                numloja = lojas[i]

            elif numloja == "24":
                alterar_loja()
                lj24()
                selecionar_loja()
                gerar_pedido()
                i = i + 1
                numloja = lojas[i]

            elif numloja == "40":
                alterar_loja()
                lj40()
                selecionar_loja()
                gerar_pedido()
                i = i + 1
                numloja = lojas[i]

            elif numloja == "12":
                alterar_loja()
                lj12()
                selecionar_loja()
                gerar_pedido()
                i = i + 1
                numloja = lojas[i]

            elif numloja == "22":
                alterar_loja()
                lj22()
                selecionar_loja()
                gerar_pedido()
                i = i + 1
                numloja = lojas[i]

            elif numloja == "8":
                alterar_loja()
                lj08()
                selecionar_loja()
                gerar_pedido()
                i = i + 1
                numloja = lojas[i]

            elif numloja == "13":
                alterar_loja()
                lj13()
                selecionar_loja()
                gerar_pedido()
                i = i + 1
                numloja = lojas[i]

            elif numloja == "15":
                alterar_loja()
                lj15()
                selecionar_loja()
                gerar_pedido()
                i = i + 1
                numloja = lojas[i]

            elif numloja == "28":
                alterar_loja()
                lj28()
                selecionar_loja()
                gerar_pedido()
                i = i + 1
                numloja = lojas[i]
                
            elif numloja == "2":
                alterar_loja()
                lj02()
                selecionar_loja()
                gerar_pedido()
                i = i + 1
                numloja = lojas[i]

            elif numloja == "11":
                alterar_loja()
                lj11()
                selecionar_loja()
                gerar_pedido()
                i = i + 1
                numloja = lojas[i]

            elif numloja == "23":
                alterar_loja()
                lj23()
                selecionar_loja()
                gerar_pedido()
                i = i + 1
                numloja = lojas[i]

            elif numloja == "19":
                alterar_loja()
                lj19()
                selecionar_loja()
                gerar_pedido()                
                numloja = ""

            else:
                numloja = None
                
        else:
            pyautogui.alert("Digite um número Valido!", title="Número  de loja errado")
            numloja = pyautogui.prompt("Digite um número de loja válido", title="Informar número da loja")

# %%
# Apos gerar os pedidos de todas as lojas, acessar o modulo de geração do arquivo do pedido ShF2
def gerar_arq_pedido():
    
    time.sleep(2)         
    pyautogui.PAUSE = 1
    pyautogui.hotkey("shift", "f2")
    pyautogui.hotkey("shift", "f3")
    pyautogui.press("enter", presses=2, interval=0.3)
    pyautogui.press("f4")
    time.sleep(3)
    pyautogui.press("f3")
    
    # Fica atento que pode acontecer de abrir uma janela antes da pagina do pedido ai será necessário precionar o F3 pra
    # sair dessa pagina e proceguir com a geração do arquivo do pedido.
    time.sleep(5)
    pyautogui.hotkey("shift", "f4")
    pyautogui.press("left", interval=0.1)
    pyautogui.press("tab")
    pyautogui.press("right", presses=2, interval=0.1)
    pyautogui.press("tab", presses=3, interval=0.3)
    pyautogui.press("space")
        
    # Escrever o nome da loja e salvar o arquivo com "enter"
    pyautogui.write (str("{}\n".format(numloja)),interval=0.2)
    pyautogui.hotkey("alt", "o")
    pyautogui.press("enter")
    pyautogui.press("f3")
    pyautogui.press("enter")
    pyautogui.press("f3")
# Repitir o processo de geração do arquivo

# %%
import sys
pyautogui.PAUSE = 0.3
try:
    
    ini_sist = pyautogui.confirm("Você está logado no sistema?", title = "Conferir sistema", buttons = ["Sim","Não"])

    if ini_sist == "Sim":
        
        pyautogui.click(x=84, y=175)
        
        try:
            opcao = pyautogui.confirm(text='Iniciar a partir de todas as lojas?', title='Selecionar a Modalidade', buttons=['Sim', 'Não'])

            if opcao == "Sim":

                try:                    
                    numfor = pyautogui.prompt("Informe o número do Fornecedor", title="Número do Fornecedor")
                    
                    if numfor:
                        
                        todas_lojas()
                        
                    else:
                        sys.exit()
                        
                except SystemExit:
                    
                    pyautogui.alert("Número fornecedor não informado!\nPrograma encerrado!", title="Alerta!")

            elif opcao == "Não":
                
                try:
                    numfor = pyautogui.prompt("Informe o número do Fornecedor", title="Número do Fornecedor")
                    
                    if numfor:
                        
                        loja_loja()
                        
                    else:
                        sys.exit()
                        
                except SystemExit:
                    
                    pyautogui.alert("Número fornecedor não informado!\nPrograma encerrado!", title="Alerta!")
                    
            else:
                sys.exit()
                
        except SystemExit:
            
            pyautogui.alert("Modalidade não informada!\nPrograma encerrado com sucesso!", title="Alerta!")
                            
    elif ini_sist == "Não":
        
        acessar_RMS()
        acessar_compras()
        time.sleep(1)
        
        pyautogui.click(x=84, y=175)
        
        try:
            opcao = pyautogui.confirm(text='Iniciar a partir de todas as lojas?', title='Selecionar a Modalidade', buttons=['Sim', 'Não'])

            if opcao == "Sim":
                
                try:
                    numfor = pyautogui.prompt("Informe o número do Fornecedor", title="Número do Fornecedor")
                    
                    if numfor:
                        
                        todas_lojas()
                        
                    else:
                        sys.exit()
                        
                except SystemExit:
                    
                    pyautogui.alert("Número fornecedor não informado!\nPrograma encerrado!", title="Alerta!")
                    

            elif opcao == "Não":
                                
                try:
                    numfor = pyautogui.prompt("Informe o número do Fornecedor", title="Número do Fornecedor")
                    
                    if numfor:
                        
                        loja_loja()
                        
                    else:
                        sys.exit()
                        
                except SystemExit:
                                        
                    pyautogui.alert("Número fornecedor não informado!\nPrograma encerrado!", title="Alerta!")
                    
            else:
                sys.exit()
                
        except SystemExit:
            
            pyautogui.alert("Modalidade não informada!\nPrograma encerrado com sucesso!", title="Alerta!")
                
    else:
        sys.exit()

except SystemExit:
    
    pyautogui.alert("Sistema encerrado com sucesso!", title="Alerta!")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\DIONLE~1\AppData\Local\Temp\62/ipykernel_33076/899155706.py in <module>
#      19                     if numfor:
#      20
# ---> 21                         todas_lojas()
#      22
#      23                     else:
#
# C:\Users\DIONLE~1\AppData\Local\Temp\62/ipykernel_33076/303150662.py in todas_lojas()
#      41             lj17()
#      42             selecionar_loja()
# ---> 43             gerar_pedido()
#      44
#      45         elif numloja == "27":
#
# C:\Users\DIONLE~1\AppData\Local\Temp\62/ipykernel_33076/1601034228.py in gerar_pedido()
#      22         pyautogui.click(x=1142, y=432)
#      23         pyautogui.press("f9")
# ---> 24         time.sleep(10)
#      25         # Ir para a próxima loja e gerar os demais pedidos...
#
# KeyboardInterrupt:

# %%
# Geração dos arquivo de pedidos diretos
time.sleep(2)

lojas = ['26','29','31','41','17','27','5','20','24','40','12','22','8','13','15','28','2','11','23','19']

i = 0

numloja = lojas[i]

while i < len(lojas):
        
    numloja = lojas[i]
    
    if numloja == "26":
        
        numloja = "Alcantara"
        gerar_arq_pedido()
        
    elif numloja == "29":
        
        numloja = "Bangu"
        gerar_arq_pedido()
        
    elif numloja == "31":
                        
        numloja = "Barra"
        gerar_arq_pedido()
        
    elif numloja == "41":
                        
        numloja = "C_Grande"
        gerar_arq_pedido()
        
    elif numloja == "17":
        
        numloja = "Cascadura"
        gerar_arq_pedido()
        
    elif numloja == "27":
                        
        numloja = "C_Neto"
        gerar_arq_pedido()
        
    elif numloja == "5":
                        
        numloja = "Copacabana"
        gerar_arq_pedido()
        
    elif numloja == "20":
        
        numloja = "Curtume"
        gerar_arq_pedido()
        
    elif numloja == "24":
                        
        numloja = "Inhauma"
        gerar_arq_pedido()
        
    elif numloja == "40":
                        
        numloja = "N_Iguacu"
        gerar_arq_pedido()
        
    elif numloja == "12":
        
        numloja = "Niteroi"
        gerar_arq_pedido()
        
    elif numloja == "22":
                        
        numloja = "P_Lucas"
        gerar_arq_pedido()
        
    elif numloja == "8":
                        
        numloja = "Pavuna"
        gerar_arq_pedido()
        
    elif numloja == "13":
        
        numloja = "Penha"
        gerar_arq_pedido()
        
    elif numloja == "15":
                        
        numloja = "Pilares"
        gerar_arq_pedido()
        
    elif numloja == "28":
                        
        numloja = "Realengo"
        gerar_arq_pedido()
        
    elif numloja == "2":
        
        numloja = "Tanque"
        gerar_arq_pedido()
        
    elif numloja == "11":
                        
        numloja = "Tiradentes"
        gerar_arq_pedido()
        
    elif numloja == "23":
                        
        numloja = "V_Cruzeiro"
        gerar_arq_pedido()
        
    elif numloja == "19":
                        
        numloja = "V_Alegre"
        gerar_arq_pedido()
                   
    else:
        pyautogui.alert("Terminou o processo!")
        loja = None
    i += 1

# %%
#7 Carregar as funções para utilização interna  
# Função de Geração do pedido direto loja

#def gerar_pedido_todas():
    
#    time.sleep(1)
#    pyautogui.PAUSE = 0.3
            
#    if numfor:
#        pyautogui.write('999')
#        pyautogui.press("enter")
#        pyautogui.press("f6")
#        pyautogui.write (str("{}\n".format(numfor)),interval=0.2)
#        pyautogui.press("enter", presses=13, interval=0.3)
#        pyautogui.write('20\n')
#        pyautogui.press("f4")
#        time.sleep(20)
#        pyautogui.press("f3")
#        pyautogui.click(x=1142, y=432)
#        pyautogui.press("f9")
#        time.sleep(10)

# %%
#numloja = pyautogui.prompt("Iniciar a partir de qual loja?", title="Informar número da loja")
#lojas = ["26","29","31","41","17","27","5","20","24","40","12","22","8","13","15","28","21","2","11","23","19"]

#i = lojas.index(numloja)
#print(len(lojas))

#for i in range(len(lojas)):
#    if numloja in lojas:
#        print(numloja)
    
#    else:
#        print("Número invalido!")
#        numloja = pyautogui.prompt("Iniciar a partir de qual loja?", title="Informar número da loja")

# %%
## import sys
#import pyautogui
#try:
#    while True:
        
#        a = pyautogui.prompt('Digite alguma coisa')
#        if a == None:
                        
#            sys.exit()

#except SystemExit:
#        pyautogui.alert('Programa encerrado com sucesso!')

# %%
    
    #import sys
#lista = ['Azul', 'Vermelho', 'Verde', 'Amarelo', 'Cinza', 'Marrom']
#for cor in lista:
#    if cor == 'Amarelo':
#        break
#    print(cor)
#sys.exit('Saindo') # Sai direto, mostrando a mensagem ao lançar a exceção
# Capturar e tratar exceção e sair
#try:
#    print("Entrou no bloco try")
#    sys.exit()
#except SystemExit:
#    print('Programa finalizado com a exceção SystemExit')
