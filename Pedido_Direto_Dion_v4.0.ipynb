# %% [markdown]
# # Projeto de digitação dos pedidos direto loja

# %% [markdown]
# ## <font color=red> Abaixo inicia o código da automação dos pedidos direto loja </font>
# ## Foi criada varias funções para execução de blocos separados no decorrer do código
# ## Será implementada classes para melhorar a interação com os blocos de códigos...

# %% [markdown]
# ## <font color=blue>Instalando a biblioteca do Pyautogui, basta executar apenas uma vez! </font>

# %%
#!pip install pyautogui

# %% [markdown]
# ## <font color=blue>Importando as bibliotecas necessárias </font>

# %%
#1 Importar todas as bibliotecas necessárias para a aplicação

# Ações do teclado e mouse
import pyautogui 

# Controle do tempo "Dá um intervalo antes da execução próxima linha de código"
import time

# Parada adequada do sistema
import sys

# %%
#2 Classe de acesso ao sistema do RMS clicando no icone de atalho na área de trabalho localizado a esquerda da tela
# Acessar o sistema RMS

class Logar_RMS:

    # metodo principal com 2 atributos, já imputados sem interação com o usuário
    
    def __init__(self, nome, senha):
        
        # Atributos da classe "Logar_RMS", que recebe os dois parâmetros do usuário
        
        self.nome = nome
        self.senha = senha
            
    # Metodo para acessar o RMS com um atalho na área de trabalho no canto esquerdo superior com as coordenadas plicadas abaixo
    
    def acessar_atalho(self):
                
        pyautogui.click(x=42, y=245, clicks=2)
        
    # Metodo de precionar a tecla "TAB" do teclado
    
    def tab(self):
                        
        pyautogui.press("tab")
        
    # Metodo de precionar a tecla "ENTER" do teclado
    
    def enter(self):
                
        pyautogui.press("enter", presses=1, interval=0.3)

# %%
#3 Está função realizar a chamada da Classe Logar_RMS e passar os parâmetros do usuário para logar no sistema
# Função lojar passando dados do usuário como nome e senha

def logar():
    
    # criando uma variável que recebe todas as caracteristicas da classe Logar_RMS
    
    acessar = Logar_RMS("luizh","121214")
    
    # Executando o metodo da classe
    
    acessar.acessar_atalho()
    
    # Aplicando um pausa de 2 segundos antes de executar o próximo código
    
    time.sleep(2)

    # Digitando o nome e a senha do usuário imputados na varíavel "acessar", que recebe os atributos das classe "Logar_RMS"
    
    pyautogui.write (str("{}\t".format(acessar.nome)),interval=0.2)
    pyautogui.write (str("{}\t".format(acessar.senha)),interval=0.2)

    # Executando o metodo da classe
    
    acessar.tab()

    # Executando o metodo da classe
    
    acessar.enter()

# %%
#4 Função para acessar o modulo de "Compras Filial"
# OBS: Com a tela Maximilizada!

def acessar_compras():
    
    time.sleep(2)    
    
    pyautogui.click(x=10, y=102)
    pyautogui.click(x=31, y=179)
    pyautogui.click(x=113, y=213, clicks=2)
    
    
# Função de troca de loja
# Acessar o modulo de troca de loja na parte inferior da tela (emogi)

def alterar_loja():
    
    time.sleep(2)
    
    pyautogui.click(x=809, y=714), voltar apos os testes
        
    
# Seleciona a loja e carrega o perfil da loja
# Função de escolha das lojas

def selecionar_loja():
    
    pyautogui.press("tab", interval=0.1)
    pyautogui.press("enter", interval=0.1)
    pyautogui.press("left", interval=0.1)
    pyautogui.press("enter", interval=0.1)

# %%
#5 Função de Geração do pedido direto loja
# Acessando o modulo de digitação dos dados do comprador padrão e o código do fornecedor

def gerar_pasta():
    
    # Aguardar um intervalo de tempo em segundos para iniciar as demais linha de código
    
    #time.sleep(1)
    
    # Dá uma pausa em segundos para execução de cada linha de código
    
    pyautogui.PAUSE = 0.5
    
    # Cria uma variável que receberá o código do fornecedor e posteriomente será usado pelo sistema
    #numfor = pyautogui.prompt("Informe o número do Fornecedor", title="Número do Fornecedor")
    
    if numfor:
        
        # digita o código do comprador padrão
        
        pyautogui.write('999')
        pyautogui.press("enter")
        
        # Acessar o modulo de sugestão do sistema (pasta de pedido)
        
        pyautogui.press("f6")
        
        # Digita o código do fornecedor informado pelo usuário
        
        pyautogui.write (str("{}\n".format(numfor)),interval=0.2)
                
        pyautogui.press("enter", presses=2, interval=1.5)
        time.sleep(1)
        
        # Caso o fornecedor tenha DEPOSITO DE TROCA será necessário alterar as quantidades de vezes do precionar o botão "DOWN"
        # para 6 vezes,caso contrario será 5 vezes.
        
        pyautogui.press("down", presses=5, interval=0.2)
        
        # Lança a sistematica do pedido
        
        pyautogui.write('20\n')
        pyautogui.press("f4")
        
        # Aguarda a geração da pasta na tela 
        
        time.sleep(10)
        
        # Fecha a janela da pasta gerada para ser ordenado por data e gerar o pedido
        
        pyautogui.press("f3")
                
        # Ordena para data mais recente
        
        pyautogui.click(x=1142, y=432)
        
        # Acessar o Gcmp para conclusão da geração da pasta de pedido internamente
        
        pyautogui.press("f9")
        time.sleep(10)
        
        # Ir para a próxima loja e gerar os demais pedidos...

# %%
#6 Função de Seleção de cada loja
# Foi criado função para cada loja e executa das funções correlacionada para geração da pasta da loja em chamada
# Cada função chama as funções de "Alternar lojas, selecionar lojas e gerar pastas" para que cada uma realize as
# alterações de acordo com a chamada individual no loop

def lj26():
    alterar_loja() # Clicar no icone parte inferior da tela do RMS "emogi" no centro, para ter acesso a opções de loja
    pyautogui.press("up", interval=0.1) # movimenta entre os nomes das lojas na janela de lojas
    selecionar_loja() # Posiciona em cima da loja escolhida e acessa a mesma
    gerar_pasta() # Inicia o processo de digitação do código do fornecedor e gera a pasta de pedido

def lj29():
    alterar_loja()
    pyautogui.press("down", presses=2, interval=0.1)
    selecionar_loja()
    gerar_pasta()    

def lj31():
    alterar_loja()
    pyautogui.press("down", presses=3, interval=0.1)
    selecionar_loja()
    gerar_pasta()
    
def lj41():
    alterar_loja()
    pyautogui.press("down", presses=4, interval=0.1)
    selecionar_loja()
    gerar_pasta()

def lj17():
    alterar_loja()
    pyautogui.press("down", presses=5, interval=0.1)
    selecionar_loja()
    gerar_pasta()

def lj27():
    alterar_loja()
    pyautogui.press("down", presses=6, interval=0.1)
    selecionar_loja()
    gerar_pasta()

def lj05():
    alterar_loja()
    pyautogui.press("down", presses=8, interval=0.1)
    selecionar_loja()
    gerar_pasta()

def lj20():
    alterar_loja()
    pyautogui.press("down", presses=9, interval=0.1)
    selecionar_loja()
    gerar_pasta()

def lj24():
    alterar_loja()
    pyautogui.press("down", presses=12, interval=0.1)
    selecionar_loja()
    gerar_pasta()

def lj40():
    alterar_loja()
    pyautogui.press("down", presses=13, interval=0.1)
    selecionar_loja()
    gerar_pasta()

def lj12():
    alterar_loja()
    pyautogui.press("down", presses=14, interval=0.1)
    selecionar_loja()
    gerar_pasta()
    
def lj22():
    alterar_loja()
    pyautogui.press("down", presses=15, interval=0.1)
    selecionar_loja()
    gerar_pasta()

def lj08():
    alterar_loja()
    pyautogui.press("down", presses=16, interval=0.1)
    selecionar_loja()
    gerar_pasta()

def lj13():
    alterar_loja()
    pyautogui.press("down", presses=17, interval=0.1)
    selecionar_loja()
    gerar_pasta()

def lj15():
    alterar_loja()
    pyautogui.press("down", presses=19, interval=0.1)
    selecionar_loja()
    gerar_pasta()

def lj28():
    alterar_loja()
    pyautogui.press("down", presses=20, interval=0.1)
    selecionar_loja()
    gerar_pasta()

def lj02():
    alterar_loja()
    pyautogui.press("down", presses=23, interval=0.1)
    selecionar_loja()
    gerar_pasta()

def lj11():
    alterar_loja()
    pyautogui.press("down", presses=24, interval=0.1)
    selecionar_loja()
    gerar_pasta()

def lj23():
    alterar_loja()
    pyautogui.press("down", presses=25, interval=0.1)
    selecionar_loja()
    gerar_pasta()

def lj19():
    alterar_loja()
    pyautogui.press("down", presses=26, interval=0.1)
    selecionar_loja()
    gerar_pasta()

# %%
#7 Função de execução de Todas as Lojas
# Função com o loop de acesso a cada loja, sequencial e execução da função de cada loja acessada.
class Rodar_Todas_Lojas:
    
    
    def __init__(self):
        
        self.lojas = ""
        
    
    def todas_lojas(self):
                                        
        # lista com número de cada loja na ordem alfabetica
        
        lojas = ['26','29','31','41','17','27','5','20','24','40','12','22','8','13','15','28','2','11','23','19']

        # Criado uma Váriavel chamada de "i" que serve como ponteiro da lista
        
        i = 0

        # Loop iniciando a parti do index Zero para primeira loja e será alterado no final de cada execução.
        
        while i < len(lojas):

            # Variável recebendo o conteúdo da lista na posição do "i" do index
            
            numloja = lojas[i]

            if numloja == "26":
                lj26()

            elif numloja == "29":
                lj29()

            elif numloja == "31":
                lj31()

            elif numloja == "41":
                lj41()

            elif numloja == "17":
                lj17()

            elif numloja == "27":
                lj27()

            elif numloja == "5":
                lj05()

            elif numloja == "20":
                lj20()

            elif numloja == "24":
                lj24()

            elif numloja == "40":
                lj40()

            elif numloja == "12":
                lj12()

            elif numloja == "22":
                lj22()

            elif numloja == "8":
                lj08()

            elif numloja == "13":
                lj13()

            elif numloja == "15":
                lj15()

            elif numloja == "28":
                lj28()

            elif numloja == "2":
                lj02()

            elif numloja == "11":
                lj11()

            elif numloja == "23":
                lj23()

            elif numloja == "19":
                lj19()

            else:
                pass

            # Index "i", recebendo um incremento para movimentar a posição da lista
            
            i += 1

        # Mensagem de alerta de conclusão da rotina da função
        
        pyautogui.alert("Todas as Pastas de Pedido foram geradas com sucesso!", title="Término da Geração das pastas!")

# %%
#8 Função com o loop de acesso loja a loja de acordo com posição infomada pelo usuário
# e execução da função de cada loja acessada dentro da lista
class Rodar_Loja_Loja:
    
    def __init__(self, numloja):
        
        self.numlj = numloja
    
    
    def loja_loja(self):
                
        # Dar uma intervelo de tempo para a execução de cada linha de código
        
        pyautogui.PAUSE = 0.3
        
        # Criando uma lisa com os números das lojas para rotação de cada loja no loop                                      
        
        lojas = ["26","29","31","41","17","27","5","20","24","40","12","22","8","13","15","28","2","11","23","19"]

        # Loop para executar o processo de cada loja
        while self.numlj:
            
            # Verificação dos dados informado pelo usuario se consta na lista
            
            if self.numlj in lojas:
                
                # Variável "i", recebe a posição da lista, obs não e conteudo!
                
                i = lojas.index(self.numlj)
                
                # Loop para acesso à cada loja de acordo com a informação passada pelo usuário
                
                while i < len(lojas):

                    if self.numlj == "26":

                        # Chama a função da loja e as demais lincadas pela função
                        lj26() 
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "29":
                        lj29()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "31":
                        lj31()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "41":
                        lj41()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "17":
                        lj17()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "27":
                        lj27()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "5":
                        lj05()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "20":
                        lj20()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "24":
                        lj24()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "40":
                        lj40()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "12":
                        lj12()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "22":
                        lj22()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "8":
                        lj08()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "13":
                        lj13()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "15":
                        lj15()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "28":
                        lj28()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "2":
                        lj02()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "11":
                        lj11()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "23":
                        lj23()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "19":
                        lj19()
                        i += 1
                        self.numlj = ""

                    else:
                        pass

                # Caixa com alerta de conclusão do processo de pedido

                pyautogui.alert("Pastas de Pedido foram geradas com sucesso!", title="Termino da Geração das pastas!")

            else:

                # Caixa com o alerta de tratamento da informação do usuário

                pyautogui.alert("Número de loja Inválido!", title="Erro Número de loja")

                # Por está dentro do loop e caindo neste "else", solicitará novamente o usuário o número da loja

                self.numlj = pyautogui.prompt("Digite um número de loja válido", title="Informar número da loja")

# %%
#9 Após gerar os pedidos de todas as lojas, acessar o modulo de geração do arquivo do pedido ShF2
# Função que realiza a tarefa de geração do arquivo em PDF dos pedidos direto

class Gerar_Arquivo:
    
    def __init__(self, numloja):
        
        self.numlj = numloja
        

    def salvar_arq_pedido(self):
        
        time.sleep(2)         
        pyautogui.PAUSE = 1
        pyautogui.hotkey("shift", "f2")
        pyautogui.hotkey("shift", "f3")
        pyautogui.press("enter", presses=2, interval=0.3)
        pyautogui.press("f4")
        time.sleep(12)

        # Fica atento que pode acontecer de abrir uma janela antes da pagina do pedido ai será necessário precionar o F3 pra
        # sair dessa pagina e proceguir com a geração do arquivo do pedido.

        pyautogui.hotkey("shift", "f4")
        time.sleep(12)
        pyautogui.press("left", interval=0.1)
        pyautogui.press("tab")
        pyautogui.press("right", presses=2, interval=0.1)
        pyautogui.press("tab", presses=3, interval=0.3)
        pyautogui.press("space")

        # Escrever o nome da loja e salvar o arquivo com "enter"
        
        time.sleep(3)
        pyautogui.write (str("{}\n".format(self.numlj)),interval=0.2)
        pyautogui.hotkey("alt", "o")
        pyautogui.press("enter")
        pyautogui.press("f3")
        pyautogui.press("enter")
        pyautogui.press("f3")

        # Repitir o processo de geração do arquivo

# %%
#10 Geração dos arquivo dos pedidos diretos
# Dá um intervalo de 2 segundos antes de executar a próxima linha de código

class Processar_Arq:
    
    def __init__(self):
        
        self.so_pra_ter = "Não serei usado..."
        
        
    def gerar_pdf_todas(self):
        
        # Criando uma lisa com os números das lojas para rotação de cada loja no loop

        lojas = ['26','29','31','41','17','27','5','20','24','40','12','22','8','13','15','28','2','11','23','19']

        # Criado uma Váriavel chamada de "i" que serve como ponteiro da lista

        i = 0

        # Loop para executar o processo de cada loja

        while i < len(lojas):

            numloja = lojas[i]

            if numloja == "26":

                numloja = "Alcantara"
                geracao = Gerar_Arquivo(numloja)
                geracao.salvar_arq_pedido()


            elif numloja == "29":

                numloja = "Bangu"
                geracao = Gerar_Arquivo(numloja)
                geracao.salvar_arq_pedido()

            elif numloja == "31":

                numloja = "Barra"
                geracao = Gerar_Arquivo(numloja)
                geracao.salvar_arq_pedido()
                
            elif numloja == "41":

                numloja = "C_Grande"
                geracao = Gerar_Arquivo(numloja)
                geracao.salvar_arq_pedido()

            elif numloja == "17":

                numloja = "Cascadura"
                geracao = Gerar_Arquivo(numloja)
                geracao.salvar_arq_pedido()

            elif numloja == "27":

                numloja = "C_Neto"
                geracao = Gerar_Arquivo(numloja)
                geracao.salvar_arq_pedido()

            elif numloja == "5":

                numloja = "Copacabana"
                geracao = Gerar_Arquivo(numloja)
                geracao.salvar_arq_pedido()

            elif numloja == "20":

                numloja = "Curtume"
                geracao = Gerar_Arquivo(numloja)
                geracao.salvar_arq_pedido()

            elif numloja == "24":

                numloja = "Inhauma"
                geracao = Gerar_Arquivo(numloja)
                geracao.salvar_arq_pedido()

            elif numloja == "40":

                numloja = "N_Iguacu"
                geracao = Gerar_Arquivo(numloja)
                geracao.salvar_arq_pedido()

            elif numloja == "12":

                numloja = "Niteroi"
                geracao = Gerar_Arquivo(numloja)
                geracao.salvar_arq_pedido()

            elif numloja == "22":

                numloja = "P_Lucas"
                geracao = Gerar_Arquivo(numloja)
                geracao.salvar_arq_pedido()

            elif numloja == "8":

                numloja = "Pavuna"
                geracao = Gerar_Arquivo(numloja)
                geracao.salvar_arq_pedido()

            elif numloja == "13":

                numloja = "Penha"
                geracao = Gerar_Arquivo(numloja)
                geracao.salvar_arq_pedido()

            elif numloja == "15":

                numloja = "Pilares"
                geracao = Gerar_Arquivo(numloja)
                geracao.salvar_arq_pedido()

            elif numloja == "28":

                numloja = "Realengo"
                geracao = Gerar_Arquivo(numloja)
                geracao.salvar_arq_pedido()

            elif numloja == "2":

                numloja = "Tanque"
                geracao = Gerar_Arquivo(numloja)
                geracao.salvar_arq_pedido()

            elif numloja == "11":

                numloja = "Tiradentes"
                geracao = Gerar_Arquivo(numloja)
                geracao.salvar_arq_pedido()

            elif numloja == "23":

                numloja = "V_Cruzeiro"
                geracao = Gerar_Arquivo(numloja)
                geracao.salvar_arq_pedido()

            elif numloja == "19":

                numloja = "V_Alegre"
                geracao = Gerar_Arquivo(numloja)
                geracao.salvar_arq_pedido()

            else:
                pass

            i += 1
            
        pyautogui.alert("Todos os arquivos dos pedidos foram gerados com sucesso!", title="Termino da geração dos arquivos!")
        
        
    def gerar_pdf_lj_lj(self,numloja):
        
        self.numlj = numloja
        
        # Criando uma lisa com os números das lojas para rotação de cada loja no loop

        lojas = ['26','29','31','41','17','27','5','20','24','40','12','22','8','13','15','28','2','11','23','19']
        
        # Loop para executar o processo de cada loja
        while self.numlj:
            
            # Verificação dos dados informado pelo usuario se consta na lista
            
            if self.numlj in lojas:
                
                # Variável "i", recebe a posição da lista, obs não e conteudo!
                
                i = lojas.index(self.numlj)
                
                # Loop para acesso à cada loja de acordo com a informação passada pelo usuário
                
                while i < len(lojas):

                    if self.numlj == "26":

                        # Chama a função da loja e as demais açoes lincadas pela função
                        numloja = "Alcantara"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "29":
                        numloja = "Bangu"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "31":
                        numloja = "Barra"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "41":
                        numloja = "C_Grande"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "17":
                        numloja = "Cascadura"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "27":
                        numloja = "C_Neto"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "5":
                        numloja = "Copacabana"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "20":
                        numloja = "Curtume"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "24":
                        numloja = "Inhauma"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "40":
                        numloja = "N_Iguacu"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "12":
                        numloja = "Niteroi"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "22":
                        numloja = "P_Lucas"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "8":
                        numloja = "Pavuna"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "13":
                        numloja = "Penha"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "15":
                        numloja = "Pilares"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "28":
                        numloja = "Realengo"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "2":
                        numloja = "Tanque"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "11":
                        numloja = "Tiradentes"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "23":
                        numloja = "V_Cruzeiro"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        i += 1
                        self.numlj = lojas[i]

                    elif self.numlj == "19":
                        numloja = "V_Alegre"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        i += 1
                        self.numlj = ""

                    else:
                        break
                    
        pyautogui.alert("Arquivos dos pedidos foram gerados com sucesso!", title="Termino da geração dos arquivos em PDF")
        
                    
    def gerar_pdf_lj(self,numloja):
        
        self.numlj = numloja
        
        # Criando uma lisa com os números das lojas para rotação de cada loja no loop

        lojas = ['26','29','31','41','17','27','5','20','24','40','12','22','8','13','15','28','2','11','23','19']
        
        # Loop para executar o processo de cada loja
        while self.numlj:
            
            # Verificação dos dados informado pelo usuario se consta na lista
            
            if self.numlj in lojas:
                
                # Variável "i", recebe a posição da lista, obs não e conteudo!
                
                i = lojas.index(self.numlj)
                
                # Loop para acesso à cada loja de acordo com a informação passada pelo usuário
                
                while i < len(lojas):

                    if self.numlj == "26":

                        # Chama a função da loja e as demais açoes lincadas pela função
                        numloja = "Alcantara"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        break                        

                    elif self.numlj == "29":
                        numloja = "Bangu"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        break
                        
                    elif self.numlj == "31":
                        numloja = "Barra"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        break                        

                    elif self.numlj == "41":
                        numloja = "C_Grande"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        break
                        

                    elif self.numlj == "17":
                        numloja = "Cascadura"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        break

                    elif self.numlj == "27":
                        numloja = "C_Neto"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        break

                    elif self.numlj == "5":
                        numloja = "Copacabana"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        break

                    elif self.numlj == "20":
                        numloja = "Curtume"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        break

                    elif self.numlj == "24":
                        numloja = "Inhauma"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        break

                    elif self.numlj == "40":
                        numloja = "N_Iguacu"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        break

                    elif self.numlj == "12":
                        numloja = "Niteroi"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        break

                    elif self.numlj == "22":
                        numloja = "P_Lucas"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        break

                    elif self.numlj == "8":
                        numloja = "Pavuna"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        break

                    elif self.numlj == "13":
                        numloja = "Penha"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        break

                    elif self.numlj == "15":
                        numloja = "Pilares"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        break

                    elif self.numlj == "28":
                        numloja = "Realengo"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        break

                    elif self.numlj == "2":
                        numloja = "Tanque"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        break

                    elif self.numlj == "11":
                        numloja = "Tiradentes"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        break

                    elif self.numlj == "23":
                        numloja = "V_Cruzeiro"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        break
                        
                    elif self.numlj == "19":
                        numloja = "V_Alegre"
                        geracao = Gerar_Arquivo(numloja)
                        geracao.salvar_arq_pedido()
                        break
                        
                    else:
                        break
                        
                self.numlj = False
            else:
                                
                # Caixa com o alerta de tratamento da informação do usuário
                
                pyautogui.alert("Número de loja Inválido!", title="Erro Número de loja")
                
                # Por está dentro do loop e caindo neste "else", solicitará novamente o usuário o número da loja
                
                self.numlj = pyautogui.prompt("Digite um número de loja válido", title="Informar número da loja")
        
        # Caixa com alerta de conclusão do processo de pedido
            
        pyautogui.alert("Arquivo do pedido foi gerado com sucesso!", title="Termino da geração do arquivo em PDF")

# %% [markdown]
# # <center>Código Principal
# # <center>Iniciar os pedidos automáticos com o código abaixo.

# %%
#11 Iniciando o processo de pedidos automático
# Neste bloco do código está sendo realizado a chamada do inicio do sistema, onde à uma interação com o usuário.
# importando a biblioteca "sys" para realizar a parada adequada no sistema de acordo com a opção escolhida.

pyautogui.PAUSE = 0.3

# Bloco de Try / Except para tratar possíveis erros na interação com o usuário.

try:
    
    ini_sist = pyautogui.confirm("Você está logado no sistema?", title = "Conferir sistema", buttons = ["Sim","Não"])

    if ini_sist == "Sim":
        
        pyautogui.click(x=84, y=175)

        try:
            
            opcao = pyautogui.confirm("Iniciar a partir de todas as lojas?", title="Selecionar modalidade de inicialização", buttons=["Sim", "Não"])

            if opcao == "Sim":

                try:
                    
                    numfor = pyautogui.prompt("Informe o número do Fornecedor", title="Número do fornecedor")
                    
                    if numfor:
                        
                        acessar_t_lojas = Rodar_Todas_Lojas()
                        acessar_t_lojas.todas_lojas()
                        
                        try:
                            
                            continua = pyautogui.confirm(text="Vai executar a geração dos arquivos PDF?", title="Geração arquivo PDF", buttons=["Sim", "Não"])
                            
                            if continua == "Sim":
                                
                                gerar_arq_pedido = Processar_Arq()
                                gerar_arq_pedido.gerar_pdf_todas()
                                
                            elif continua == "Não":
                                
                                pyautogui.alert("Programa encerrado com sucesso!", title="Finalização do programa")
                                
                            else:
                                sys.exit()
                        
                        except SystemExit:
                            
                            pyautogui.alert("Opção não informada!\n O Programa foi encerrado!", title="Sistema fechado sem opção")
                            
                    else:
                        sys.exit()
                        
                except SystemExit:
                    
                    pyautogui.alert("Número do fornecedor não informado!\nPrograma encerrado com sucesso!", title="Erro no número do fornecedor")

            elif opcao == "Não":
                
                try:
                    
                    numloja = pyautogui.prompt("Iniciar a partir de qual loja?", title="Número da loja")
                    numfor = pyautogui.prompt("Informe o número do fornecedor", title="Número do fornecedor")
                    
                    if numloja and numfor:
                        
                        acessar_l_loja = Rodar_Loja_Loja(numloja)
                        acessar_l_loja.loja_loja()
                                                                        
                    else:
                        sys.exit()
                        
                except SystemExit:
                    
                    pyautogui.alert("Número da loja ou do fornecedor não informado!\nPrograma encerrado!", title="Alerta!")
                    
            else:
                sys.exit()
                
        except SystemExit:
            
            pyautogui.alert("Modalidade não informada!\nPrograma encerrado com sucesso!", title="Fechamento do Sistema!")
#---------------------------------------------------------------------------------------------------------------------------------------------------        
    elif ini_sist == "Não":
        
        logar()
        time.sleep(1)
        pyautogui.press("enter")
        time.sleep(2)
        acessar_compras()
        time.sleep(1)
        
        pyautogui.click(x=84, y=175)

        try:
            
            opcao = pyautogui.confirm("Iniciar a partir de todas as lojas?", title="Selecionar modalidade de inicialização", buttons=["Sim", "Não"])

            if opcao == "Sim":

                try:
                    
                    numfor = pyautogui.prompt("Informe o número do Fornecedor", title="Número do fornecedor")
                    
                    if numfor:
                        
                        acessar_t_lojas = Rodar_Todas_Lojas()
                        acessar_t_lojas.todas_lojas()
                            
                    else:
                        sys.exit()
                        
                except SystemExit:
                    
                    pyautogui.alert("Número do fornecedor não informado!\nPrograma encerrado com sucesso!", title="Erro no número do fornecedor")

            elif opcao == "Não":
                
                try:
                    
                    numloja = pyautogui.prompt("Iniciar a partir de qual loja?", title="Número da loja")
                    numfor = pyautogui.prompt("Informe o número do fornecedor", title="Número do fornecedor")
                    
                    if numloja and numfor:
                        
                        acessar_l_loja = Rodar_Loja_Loja(numloja)
                        acessar_l_loja.loja_loja()
                                                
                    else:
                        sys.exit()
                        
                except SystemExit:
                    
                    pyautogui.alert("Número da loja ou do fornecedor não informado!\nPrograma encerrado!", title="Alerta!")
                    
            else:
                sys.exit()
                
        except SystemExit:
            
            pyautogui.alert("Modalidade não informada!\nPrograma encerrado com sucesso!", title="Fechamento do Sistema!")
                
    else:
        sys.exit()

except SystemExit:
    
    pyautogui.alert("Sistema da 1ª etapa encerrado com sucesso!", title="Fechamento do sistema!")

# %% [markdown]
# # <center>Código De Geração dos Arquivos PDFs
# ## <center>Modalidade de geração dos arquivos em PDFs fora do processo automático
# ## <center><font color=red>OBS: Certifique que esteja logado com uma loja e com o comprador!

# %%
import pyautogui
import time
pyautogui.PAUSE = 0.3

inicio = pyautogui.confirm(text="Inicio da 2ª Etapa \nIniciar o Sistema de Geração dos Arquivos em PDF?", title="Sistema de Geração de Arquivos PDF!", buttons=["Sim","Não"])

if inicio == "Sim":
    
    modo = pyautogui.confirm(text="Iniciar a Geração a parti de todas as lojas?", title="Escolha da Modalidade de Geração", buttons=["Sim","A parti de","Somente uma loja"])
    pyautogui.click(x=235, y=394)
    
    if modo == "Sim":
                
        gerar_arq_pedido = Processar_Arq()
        gerar_arq_pedido.gerar_pdf_todas()
    
    elif modo == "A parti de":
        
        numlj = pyautogui.prompt(text="Iniciar a partir de qual loja?", title="Número da loja")
        
        gerar_arq_pedido = Processar_Arq()
        gerar_arq_pedido.gerar_pdf_lj_lj(numlj)
        
        
    elif modo == "Somente uma loja":
        
        numlj = pyautogui.prompt(text="Informe o número da loja?", title="Número da loja")
        
        gerar_arq_pedido = Processar_Arq()
        gerar_arq_pedido.gerar_pdf_lj(numlj)
        

    else:
        pyautogui.alert(text="Você desistiu \U0001F625 Que pena!\n\nO programa foi encerrado!", title="Desistência \U0001F914")
        
    
elif inicio == "Não":
    pyautogui.alert(text="Programa encerrado com sucesso!", title="Encerramento do Programa...")

else:
    pyautogui.alert(text="O programa foi fechado!", title="Opção inválida!!!")
